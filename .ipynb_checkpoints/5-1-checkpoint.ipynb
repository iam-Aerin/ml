# %% [markdown]
# # 5-1. 결정 트리 (p.220)
# > 결정 트리 알고리즘
# >
# > 표준 점수화를 안해도 된다.
# 선형이 아닌 데이터는?
# 레드와인인지 화이트화인인지 라벨링을 해보자.

# %% [markdown]
# #### 1) 먼저 로지스틱 회귀로 와인 데이터 (레드 /화이트 와인) 을 분류해보자

# %%
import pandas as pd

red_wine = pd.read_csv('data/winequality-red.csv', sep=';')
# wine의 데이터가 구분점이 ,(콤마)가 아닌 :(세미콜론)으로 나눠져있어서 => 코드에 구분점이 (;) 라고 알려줌.

white_wine = pd.read_csv('data/winequality-white.csv', sep=';')

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
# 필요한 열만 가져오기 
red_wine = red_wine[['alcohol', 'residual sugar', 'pH']]

# 컬럼 이름 변경
red_wine.rename(columns={'residual sugar': 'sugar'}, inplace=True)

# 새로운 컬럼(class) 추가
red_wine['class'] = 0
# 레드 와인이라면 class가 0
# 데이터 확인
red_wine.head()
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51      0
# 1      9.8    2.6  3.20      0
# 2      9.8    2.3  3.26      0
# 3      9.8    1.9  3.16      0
# 4      9.4    1.9  3.51      0

# %%
white_wine = white_wine[['alcohol', 'residual sugar', 'pH']]
white_wine.rename(columns={'residual sugar': 'sugar'}, inplace=True)
white_wine['class'] = 1

# 화이트 와인이라면 class가 1

# %%
# 이렇게 만든 red_wine 데이터와 white_wine 데이터를 하나로 합치기 
# concat

wine = pd.concat([red_wine, white_wine])
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   int64
# dtypes: float64(3), int64(1)
# memory usage: 253.8 KB

# %%
# 데이터를 랜덤하게 분류해보자 
# 학습과 정답 데이터로 

data = wine[['alcohol', 'sugar', 'pH']]
target = wine[['class']]

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = \
train_test_split(data, target)

# %%
# 로지스틱 회귀를 먼저 해보기 위해
# 표준 점수화 부터 해주자
# 사실 decision tree 의사결정나무에서는 표준 점수화를 안해줘도 된다!!!!!!!!!!!!!

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(train_input)
train_scaled = ss.transform(train_input)
test_scaled = ss.transform(test_input)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(train_scaled, train_target)
print(lr.score(train_scaled, train_target))

print(lr.score(test_scaled, test_target))
# Out:
# 0.7803776683087028
# 0.7784615384615384
# C:\Users\박수똥\Desktop\DAMF2\ml\venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# 무조건 도수가 낮다고 화이트 와인, 레드와인? 이라고 할 수 없다.
# 선형 관계를 띄지 않는다.
# => 그래서 이건 로지스틱 회귀로 표현하기에 맞지 않는다.
# 결정 트리 모델을 써보자

# %% [markdown]
# #### 2) 결정 트리 모델로 와인 데이터 (레드 /화이트 와인)를 분류해보자
# > 와인 데이터는 선형 구조를 띄지 않기에

# %%
from sklearn.tree import DecisionTreeClassifier

# dt = DecisionTreeClassifier()
dt = DecisionTreeClassifier(max_depth=90)
# 가지치기를 해줌 (max_depth에 값을 지정해줌으로써)

dt.fit(train_scaled, train_target)

print(dt.score(train_scaled, train_target))
print(dt.score(test_scaled, test_target))

#로지스틱 회귀 모델 대비 성능이 많이 올라간 것을 확인할 수 있다.
# Out:
# 0.9973316912972086
# 0.8683076923076923

# %%
# 이 결정 트리 모델을 시각화해서 표현해보자
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 7))
plot_tree(dt)

plt.show()

# 적절하게 가지치기를  해주는게 중요하다.

# %%
# decision tree의 전체를 시각화 => max_depth=1로 줌으로써 맨 앞부분의 tree의 모습을 확인해보자

import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 7))
plot_tree(dt, max_depth=1)

plt.show()
